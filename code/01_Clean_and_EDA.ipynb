# %% [markdown]
# ### Notebook 1: Cleaning & EDA for Scotch Recommender

# %% [markdown]
# Here are the necessary imports:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Import the Scotch Dataset. This is a Kaggle dataset found here: https://www.kaggle.com/koki25ando/scotch-whisky-dataset

# %%
scotch_df = pd.read_csv('data/whisky.csv')
scotch_df
# Out:
#     RowID    Distillery  Body  Sweetness  Smoky  Medicinal  Tobacco  Honey  \
# 0       1     Aberfeldy     2          2      2          0        0      2
# 1       2      Aberlour     3          3      1          0        0      4
# 2       3        AnCnoc     1          3      2          0        0      2
# 3       4        Ardbeg     4          1      4          4        0      0
# 4       5       Ardmore     2          2      2          0        0      1
# ..    ...           ...   ...        ...    ...        ...      ...    ...
# 81     82     Tobermory     1          1      1          0        0      1
# 82     83       Tomatin     2          3      2          0        0      2
# 83     84     Tomintoul     0          3      1          0        0      2
# 84     85       Tormore     2          2      1          0        0      1
# 85     86  Tullibardine     2          3      0          0        1      0
#
#     Spicy  Winey  Nutty  Malty  Fruity  Floral    Postcode  Latitude  \
# 0       1      2      2      2       2       2  \tPH15 2EB    286580
# 1       3      2      2      3       3       2  \tAB38 9PJ    326340
# 2       0      0      2      2       3       2   \tAB5 5LI    352960
# 3       2      0      1      2       1       0  \tPA42 7EB    141560
# 4       1      1      2      3       1       1  \tAB54 4NH    355350
# ..    ...    ...    ...    ...     ...     ...         ...       ...
# 81      0      0      1      2       2       2    PA75 6NR    150450
# 82      2      1      1      2       0       1    IV13 7YT    279120
# 83      2      1      1      2       1       2    AB37 9AQ    315100
# 84      0      1      2      1       0       0    PH26 3LR    315180
# 85      2      1      1      2       2       1     PH4 1QG    289690
#
#     Longitude
# 0      749680
# 1      842570
# 2      839320
# 3      646220
# 4      829140
# ..        ...
# 81     755070
# 82     829630
# 83     825560
# 84     834960
# 85     708850
#
# [86 rows x 17 columns]

# %%
scotch_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86 entries, 0 to 85
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   RowID       86 non-null     int64
#  1   Distillery  86 non-null     object
#  2   Body        86 non-null     int64
#  3   Sweetness   86 non-null     int64
#  4   Smoky       86 non-null     int64
#  5   Medicinal   86 non-null     int64
#  6   Tobacco     86 non-null     int64
#  7   Honey       86 non-null     int64
#  8   Spicy       86 non-null     int64
#  9   Winey       86 non-null     int64
#  10  Nutty       86 non-null     int64
#  11  Malty       86 non-null     int64
#  12  Fruity      86 non-null     int64
#  13  Floral      86 non-null     int64
#  14  Postcode    86 non-null     object
#  15  Latitude    86 non-null     int64
#  16  Longitude   86 non-null     int64
# dtypes: int64(15), object(2)
# memory usage: 11.5+ KB

# %% [markdown]
# Right away I can see that not much cleaning is needed here. There aren't any null values. For now, I think I can just drop the RowID and the Postcode columns and move forward. I'm not sure how I'm going to use the Lat/Long data yet, I will just keep that information in there for now.

# %%
scotch_df = scotch_df.drop(['RowID', 'Postcode'], axis = 1)
scotch_df.head(2)
# Out:
#   Distillery  Body  Sweetness  Smoky  Medicinal  Tobacco  Honey  Spicy  Winey  \
# 0  Aberfeldy     2          2      2          0        0      2      1      2
# 1   Aberlour     3          3      1          0        0      4      3      2
#
#    Nutty  Malty  Fruity  Floral  Latitude  Longitude
# 0      2      2       2       2    286580     749680
# 1      2      3       3       2    326340     842570

# %% [markdown]
# Now onto the EDA: I'd like to explore the different scotch attributes. My personal favorite scotches are the real peaty/smoky ones, so I'd like to explore the scotches that have the most Body, Smoky, and Medicinal attributes.

# %%
scotch_df.describe()
# Out:
#             Body  Sweetness      Smoky  Medicinal    Tobacco      Honey  \
# count  86.000000  86.000000  86.000000  86.000000  86.000000  86.000000
# mean    2.069767   2.290698   1.534884   0.546512   0.116279   1.244186
# std     0.930410   0.717287   0.863613   0.990032   0.322439   0.853175
# min     0.000000   1.000000   0.000000   0.000000   0.000000   0.000000
# 25%     2.000000   2.000000   1.000000   0.000000   0.000000   1.000000
# 50%     2.000000   2.000000   1.000000   0.000000   0.000000   1.000000
# 75%     2.000000   3.000000   2.000000   1.000000   0.000000   2.000000
# max     4.000000   4.000000   4.000000   4.000000   1.000000   4.000000
#
#            Spicy      Winey      Nutty      Malty     Fruity     Floral  \
# count  86.000000  86.000000  86.000000  86.000000  86.000000  86.000000
# mean    1.383721   0.976744   1.465116   1.802326   1.802326   1.697674
# std     0.784686   0.932760   0.821730   0.629094   0.779438   0.855017
# min     0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 25%     1.000000   0.000000   1.000000   1.000000   1.000000   1.000000
# 50%     1.000000   1.000000   2.000000   2.000000   2.000000   2.000000
# 75%     2.000000   1.000000   2.000000   2.000000   2.000000   2.000000
# max     3.000000   4.000000   4.000000   3.000000   3.000000   4.000000
#
#             Latitude     Longitude
# count      86.000000  8.600000e+01
# mean   287247.162791  8.026597e+05
# std     67889.046814  8.802422e+04
# min    126680.000000  5.542600e+05
# 25%    265672.500000  7.556975e+05
# 50%    319515.000000  8.398850e+05
# 75%    328630.000000  8.507700e+05
# max    381020.000000  1.009260e+06

# %% [markdown]
# Each flavor/profile category has a range from 0-4, so if I wanted to see the smokiest scotches, I would look for those with Smoky = 3 or 4.

# %%
#What are the smokiest scotches? I want to see which scotches are smokiest.
smokiest = scotch_df[scotch_df['Smoky'] > 2]
smokiest
# Out:
#        Distillery  Body  Sweetness  Smoky  Medicinal  Tobacco  Honey  Spicy  \
# 3          Ardbeg     4          1      4          4        0      0      2
# 18        Bowmore     2          2      3          1        0      2      2
# 21       Caol Ila     3          1      4          2        1      0      2
# 23      Clynelish     3          2      3          3        1      0      2
# 34    GlenGarioch     2          1      3          0        0      0      3
# 53  Highland Park     2          2      3          1        0      2      1
# 57      Lagavulin     4          1      4          4        1      0      1
# 58       Laphroig     4          2      4          4        1      0      0
# 77       Talisker     4          2      3          3        0      1      3
#
#     Winey  Nutty  Malty  Fruity  Floral  Latitude  Longitude
# 3       0      1      2       1       0    141560     646220
# 18      1      1      1       1       2    131330     659720
# 21      0      2      1       1       1    142920     670040
# 23      0      1      1       2       0    290250     904230
# 34      1      0      2       2       2    381020     827590
# 53      1      1      2       1       1    345340    1009260
# 57      2      1      1       1       0    140430     645730
# 58      1      1      1       0       0    138680     645160
# 77      0      1      2       2       0    137950     831770

# %% [markdown]
# This result makes sense, as some of my favorite scotches are Ardbeg and Laphroaig. Already I'm seeing some scotches I need to try!

# %%
#What are the most Medicinal scotches? 
medicinal = scotch_df[scotch_df['Medicinal'] > 2]
medicinal
# Out:
#    Distillery  Body  Sweetness  Smoky  Medicinal  Tobacco  Honey  Spicy  \
# 3      Ardbeg     4          1      4          4        0      0      2
# 23  Clynelish     3          2      3          3        1      0      2
# 57  Lagavulin     4          1      4          4        1      0      1
# 58   Laphroig     4          2      4          4        1      0      0
# 77   Talisker     4          2      3          3        0      1      3
#
#     Winey  Nutty  Malty  Fruity  Floral  Latitude  Longitude
# 3       0      1      2       1       0    141560     646220
# 23      0      1      1       2       0    290250     904230
# 57      2      1      1       1       0    140430     645730
# 58      1      1      1       0       0    138680     645160
# 77      0      1      2       2       0    137950     831770

# %% [markdown]
# There are only 5 of those most medicinal scotches, but they are also in the smoky category as well.

# %%
#What are the most Fruity scotches? 
fruity = scotch_df[scotch_df['Fruity'] > 2]
fruity
# Out:
#         Distillery  Body  Sweetness  Smoky  Medicinal  Tobacco  Honey  Spicy  \
# 1         Aberlour     3          3      1          0        0      4      3
# 2           AnCnoc     1          3      2          0        0      2      0
# 6     Auchentoshan     0          2      0          0        0      1      1
# 13        Benriach     2          2      1          0        0      2      2
# 27         Dalmore     3          2      2          1        0      1      2
# 43      Glendullan     3          2      1          0        0      2      1
# 46       Glengoyne     1          2      0          0        0      1      1
# 59        Linkwood     2          3      1          0        0      1      1
# 62        Macallan     4          3      1          0        0      2      1
# 69    RoyalBrackla     2          3      2          1        1      1      2
# 70  RoyalLochnagar     3          2      2          0        0      2      2
# 75      Strathisla     2          2      1          0        0      2      2
# 76      Strathmill     2          3      1          0        0      0      2
#
#     Winey  Nutty  Malty  Fruity  Floral  Latitude  Longitude
# 1       2      2      3       3       2    326340     842570
# 2       0      2      2       3       2    352960     839320
# 6       0      2      2       3       3    247670     672610
# 13      0      0      2       3       2    323450     858380
# 27      2      1      2       3       1    266610     868730
# 43      2      1      2       3       2    333000     840300
# 46      1      2      2       3       2    252810     682750
# 59      2      0      1       3       2    322640     861040
# 62      4      2      2       3       1    327710     844480
# 69      1      0      2       3       2    286040     851320
# 70      2      2      2       3       1    326140     794370
# 75      2      3      3       3       2    340754     848623
# 76      0      2      1       3       2    342650     850500

# %% [markdown]
# It seems like maybe the Smoky and Medicinal Flavors might be inversely related to the Sweet/Fruity Flavors, which makes sense.

# %% [markdown]
# I would like to try a clustering project to see if I can group these scotches together.
